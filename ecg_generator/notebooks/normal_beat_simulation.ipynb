# %%
# First, install the import_ipynb package
#this is mandatory step in order to run the project
# !pip install import_ipynb
import import_ipynb
from signal_generator import generate_normal_ecg
from peak_detection import detect_r_peaks, compute_heart_rate
from visualization import plot_peaks

# %%
# Generate normal ECG
t, signal = generate_normal_ecg()

# Detect R-peaks
peak_times, peaks = detect_r_peaks(signal, t)

# Compute heart rate
heart_rate = compute_heart_rate(peak_times)
print("Heart Rate:", heart_rate, "BPM")

# Plot ECG with detected peaks
plot_peaks(t, signal, peak_times, peaks)
# Out:
# Heart Rate: 59.99 BPM
